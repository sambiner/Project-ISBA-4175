# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (0.4.1)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (1.4.39)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlparse in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython>=1.0 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (7.31.1)
# Requirement already satisfied: prettytable<1 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.36)
# Requirement already satisfied: matplotlib-inline in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: colorama in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.6)
# Requirement already satisfied: pygments in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: backcall in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (5.7.1)
# Requirement already satisfied: decorator in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from ipython>=1.0->ipython-sql) (65.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (2.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\sambi\anaconda3\envs\isba_4715_sql\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.3-py3-none-any.whl (43 kB)
#      ---------------------------------------- 43.7/43.7 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.3

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# # SQL Queries and Data Analysis

# %% [markdown]
# ## Exploratory SQL Queries for Data Familiarity

# %%
# %%sql
# SELECT ct.company_id,
#     c.company_name,
#     COUNT(tool_id) AS tool_frequency
# FROM Companies c
# JOIN Company_Tool ct
#     ON c.company_id = ct.company_id
# GROUP BY company_id;
# Out:
#  * mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
# 20 rows affected.
# [(20, 'AutoNation', 12),
#  (19, 'Occidental Petroleum Corporation', 25),
#  (18, 'NRG Energy, Incorporated', 25),
#  (3, 'Valero Energy Corporation', 9),
#  (16, 'CBRE Group, Incorporated', 0),
#  (11, 'StoneX Group Incorporated', 0),
#  (4, 'Centene Corporation', 0),
#  (17, 'United Natural Foods, Incorporated', 23),
#  (15, 'Visa Incorporated', 25),
#  (14, 'The Traverlers Companies, Incorporated', 25),
#  (13, 'General Dynamics Corporation', 18),
#  (12, 'Publix Super Markets, Incorporated', 25),
#  (10, 'Aetna Incorporated', 25),
#  (9, 'Wells Fargo & Company', 25),
#  (8, 'General Electric Company', 25),
#  (7, 'Citigroup Incorporated', 17),
#  (6, 'PepsiCo Incorporated', 12),
#  (5, 'Pfizer Incorporated', 25),
#  (2, 'The Home Depot, Incorporated', 25),
#  (1, 'Costco Wholesale Corporation', 25)]

# %% [markdown]
# This query is for the purpose of checking if all of the companies have the correct number
#  of tools given what the API is able to give me.

# %%
# %%sql
# SELECT company_name, company_revenue
# FROM Companies
# ORDER BY company_revenue DESC
# LIMIT 5;
# Out:
#  * mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
# 5 rows affected.
# [('Costco Wholesale Corporation', 226950000000),
#  ('The Home Depot, Incorporated', 151160000000),
#  ('Valero Energy Corporation', 117033000000),
#  ('Centene Corporation', 111115000000),
#  ('Pfizer Incorporated', 100300000000)]

# %% [markdown]
# This query retrieves the names and revenues of KPMG's top 5 clients based on revenue, allowing me to understand which companies are the most financially successful

# %%
# %%sql
# SELECT AVG(company_size) as average_size
# FROM Companies;
# Out:
#  * mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
# 1 rows affected.
# [(Decimal('129623.7000'),)]

# %% [markdown]
# Calculating the average company size of all companies within the Companies table. This helps provide an insight into the typical size among the top 20 of KPMG's clients

# %%
# %%sql
# SELECT
#     t.tool_name,
#     COUNT(ct.company_id) as company_count
# FROM Tools t
# JOIN Company_Tool ct
#     ON t.tool_id = ct.tool_id
# GROUP BY t.tool_name
# ORDER BY company_count DESC;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 126 rows affected.
# [('jQuery', 17),
#  ('ASP.NET', 14),
#  ('Bootstrap', 14),
#  ('Amazon Web Services', 13),
#  ('IIS', 12),
#  ('Google Tag Manager', 12),
#  ('Apache', 11),
#  ('NGINX', 11),
#  ('Modernizr', 10),
#  ('Font Awesome', 9),
#  ('Varnish', 9),
#  ('Microsoft Azure', 8),
#  ('jQuery UI', 8),
#  ('Google Fonts', 8),
#  ('Akamai', 7),
#  ('Windows Server', 6),
#  ('AngularJS', 6),
#  ('Drupal', 6),
#  ('Ensighten', 5),
#  ('Adobe DTM', 5),
#  ('Google Analytics', 4),
#  ('CloudFlare', 4),
#  ('React', 4),
#  ('Ruby', 4),
#  ('RequireJS', 4),
#  ('Adobe Experience Manager', 4),
#  ('ZURB Foundation', 4),
#  ('Lodash', 4),
#  ('WordPress', 4),
#  ('jQuery Migrate', 4),
#  ('MongoDB', 3),
#  ('PHP', 3),
#  ('Acquia', 3),
#  ('Rails', 3),
#  ('Underscore.js', 3),
#  ('Incapsula', 3),
#  ('Slick', 3),
#  ('reCAPTCHA', 3),
#  ('Amazon CloudFront', 3),
#  ('Google Cloud', 3),
#  ('F5 BigIP', 2),
#  ('Sitecore', 2),
#  ('Node.js', 2),
#  ('ruxit', 2),
#  ('Percona', 2),
#  ('Lightbox', 2),
#  ('Amazon EC2', 2),
#  ('Java', 2),
#  ('OpenSSL', 2),
#  ('ESLint', 2),
#  ('Amazon S3', 2),
#  ('AddThis', 2),
#  ('Handlebars.js', 2),
#  ('YouTube', 2),
#  ('Pantheon', 2),
#  ('Yoast SEO', 2),
#  ('Animate.css', 2),
#  ('SiteCatalyst', 2),
#  ('Apache Tomcat', 2),
#  ('SWFObject', 1),
#  ('Sass', 1),
#  ('C#', 1),
#  ('SonarQube', 1),
#  ('Protractor', 1),
#  ('Ionic', 1),
#  ('Azure Functions', 1),
#  ('Swagger UI', 1),
#  ('Git', 1),
#  ('Microsoft SQL Server', 1),
#  ('Visual Studio Code', 1),
#  ('.NET', 1),
#  ('Objective-C', 1),
#  ('npm', 1),
#  ('Confluence', 1),
#  ('Jira', 1),
#  ('Azure DevOps Server', 1),
#  ('Material Design for Angular', 1),
#  ('RabbitMQ', 1),
#  ('Angular', 1),
#  ('Ubuntu', 1),
#  ('Typekit', 1),
#  ('Webtrends', 1),
#  ('Microsoft SharePoint', 1),
#  ('UNIX', 1),
#  ('Clicky', 1),
#  ('Google PageSpeed', 1),
#  ('Optimizely', 1),
#  ('Gradle', 1),
#  ('Chai', 1),
#  ('Puma', 1),
#  ('SinonJS', 1),
#  ('Dynatrace', 1),
#  ('Prototype', 1),
#  ('Netlify', 1),
#  ('XRegExp', 1),
#  ('Google Maps', 1),
#  ('Mimecast', 1),
#  ('fancybox', 1),
#  ('WordPress Super Cache', 1),
#  ('OWL Carousel', 1),
#  ('amCharts', 1),
#  ('Select2', 1),
#  ('MooTools', 1),
#  ('CentOS', 1),
#  ('Twitter typeahead.js', 1),
#  ('Chart.js', 1),
#  ('Java Servlet', 1),
#  ('SAML', 1),
#  ('Sitefinity', 1),
#  ('TweenMax', 1),
#  ('Dyn', 1),
#  ('New Relic', 1),
#  ('Azure CDN', 1),
#  ('Jenkins', 1),
#  ('Polyfill', 1),
#  ('Moment.js', 1),
#  ('Enzyme', 1),
#  ('Material Design Lite', 1),
#  ('Jest', 1),
#  ('Travis CI', 1),
#  ('Shell', 1),
#  ('Prettier', 1),
#  ('Apigee', 1),
#  ('IBM Bluemix', 1),
#  ('IBM WebSphere Commerce', 1),
#  ('Xamarin', 1)]

# %% [markdown]
# Retrieves the number of companies using each individual tool, giving an idea on which tools are most popular among KPMG's top 20 clients.

# %%
# %%sql
# SELECT DISTINCT t.tool_name
# FROM Tools t
# JOIN Company_Tool ct
#     ON t.tool_id = ct.tool_id
# JOIN Companies c
#     ON ct.company_id = c.company_id
# WHERE c.company_revenue > (
#     SELECT AVG(company_revenue)
#     FROM Companies
# )
# ORDER BY t.tool_name;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 81 rows affected.
# [('Acquia',),
#  ('Adobe DTM',),
#  ('Adobe Experience Manager',),
#  ('Akamai',),
#  ('Amazon CloudFront',),
#  ('Amazon EC2',),
#  ('Amazon S3',),
#  ('Amazon Web Services',),
#  ('amCharts',),
#  ('AngularJS',),
#  ('Animate.css',),
#  ('Apache',),
#  ('Apache Tomcat',),
#  ('Apigee',),
#  ('ASP.NET',),
#  ('Azure CDN',),
#  ('Bootstrap',),
#  ('CentOS',),
#  ('Chart.js',),
#  ('CloudFlare',),
#  ('Drupal',),
#  ('Dyn',),
#  ('Ensighten',),
#  ('Enzyme',),
#  ('ESLint',),
#  ('F5 BigIP',),
#  ('Font Awesome',),
#  ('Google Analytics',),
#  ('Google Cloud',),
#  ('Google Fonts',),
#  ('Google Tag Manager',),
#  ('Handlebars.js',),
#  ('IBM Bluemix',),
#  ('IBM WebSphere Commerce',),
#  ('IIS',),
#  ('Incapsula',),
#  ('Java',),
#  ('Java Servlet',),
#  ('Jenkins',),
#  ('Jest',),
#  ('jQuery',),
#  ('jQuery Migrate',),
#  ('jQuery UI',),
#  ('Lightbox',),
#  ('Lodash',),
#  ('Material Design Lite',),
#  ('Microsoft Azure',),
#  ('Microsoft SharePoint',),
#  ('Modernizr',),
#  ('Moment.js',),
#  ('MongoDB',),
#  ('MooTools',),
#  ('New Relic',),
#  ('NGINX',),
#  ('Node.js',),
#  ('OpenSSL',),
#  ('Pantheon',),
#  ('Percona',),
#  ('Polyfill',),
#  ('Prettier',),
#  ('Rails',),
#  ('React',),
#  ('RequireJS',),
#  ('Ruby',),
#  ('ruxit',),
#  ('SAML',),
#  ('Select2',),
#  ('Shell',),
#  ('SiteCatalyst',),
#  ('Sitefinity',),
#  ('Slick',),
#  ('Travis CI',),
#  ('TweenMax',),
#  ('Twitter typeahead.js',),
#  ('Underscore.js',),
#  ('Varnish',),
#  ('Webtrends',),
#  ('Windows Server',),
#  ('WordPress',),
#  ('Yoast SEO',),
#  ('ZURB Foundation',)]

# %% [markdown]
# Lists all individual tools used by companies with a revenue greater than the average revenue of KPMG's top 20 clients.  This could help me to identify the tech stack that is preferred by large, high-revenue companies

# %%
# %%sql
# WITH SmallestCompanies AS (
#   SELECT company_id
#   FROM Companies
#   ORDER BY company_size
#   LIMIT 5
# )
# SELECT
#     t.tool_name,
#     COUNT(ct.company_id) as company_count
# FROM Tools t
# JOIN Company_Tool ct
#     ON t.tool_id = ct.tool_id
# JOIN SmallestCompanies sc
#     ON ct.company_id = sc.company_id
# GROUP BY t.tool_name
# ORDER BY company_count DESC
# LIMIT 5;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 5 rows affected.
# [('Bootstrap', 4),
#  ('jQuery', 4),
#  ('Amazon Web Services', 3),
#  ('ASP.NET', 3),
#  ('Microsoft Azure', 3)]

# %% [markdown]
# Retrieves the top 5 technologies that are used by the 5 lowest-revenue clients, which I believe is a valuable insight because I can understand the technology preferred by slightly smaller organizations.

# %%
# %%sql
# CREATE VIEW company_tool_count AS
# SELECT
#     c.company_id,
#     c.company_name,
#     c.company_domain,
#     c.company_size,
#     c.company_revenue,
#     COUNT(t.tool_id) AS tool_count
# FROM Companies c
# JOIN Company_Tool ct ON c.company_id = ct.company_id
# JOIN Tools t ON ct.tool_id = t.tool_id
# GROUP BY
#     c.company_id,
#     c.company_name,
#     c.company_domain,
#     c.company_size,
#     c.company_revenue;

# %%
# %%sql
# SELECT *
# FROM company_tool_count
# ORDER BY tool_count DESC;

# %% [markdown]
# These two queries are first to create a view that gives data on which companies have tool data associated with them and the second is to sort the view to see the companies with the most tool data associated with them.

# %% [markdown]
# ## Main queries to answer and solve my business problem

# %%
# %%sql
# SELECT tool_name,
#     COUNT(ct.tool_id) AS tool_frequency
# FROM Tools t
# JOIN Company_Tool ct
#     ON t.tool_id = ct.tool_id
# GROUP BY ct.tool_id
# ORDER BY COUNT(ct.tool_id) DESC
# LIMIT 5;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 5 rows affected.
# [('jQuery', 17),
#  ('ASP.NET', 14),
#  ('Bootstrap', 14),
#  ('Amazon Web Services', 13),
#  ('Google Tag Manager', 12)]

# %%
# %%sql
# WITH average_tools AS (
#     SELECT company_name,
#         tool_name,
#         COUNT(ct.tool_id) AS tool_count
#     FROM Company_Tool ct
#     RIGHT JOIN Companies c
#         ON ct.company_id = c.company_id
#     LEFT JOIN Tools t
#         ON ct.tool_id = t.tool_id
#     GROUP BY ct.tool_id
#     HAVING COUNT(ct.tool_id) = 1
#     ORDER BY COUNT(ct.tool_id) DESC
# )
# SELECT *
# FROM average_tools
# ORDER BY company_name;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 67 rows affected.
# [('Aetna Incorporated', 'fancybox', 1),
#  ('Aetna Incorporated', 'Mimecast', 1),
#  ('Aetna Incorporated', 'OWL Carousel', 1),
#  ('Aetna Incorporated', 'WordPress Super Cache', 1),
#  ('AutoNation', 'SWFObject', 1),
#  ('Citigroup Incorporated', 'SAML', 1),
#  ('Citigroup Incorporated', 'Java Servlet', 1),
#  ('Costco Wholesale Corporation', 'IBM Bluemix', 1),
#  ('Costco Wholesale Corporation', 'IBM WebSphere Commerce', 1),
#  ('Costco Wholesale Corporation', 'Apigee', 1),
#  ('General Electric Company', 'CentOS', 1),
#  ('General Electric Company', 'Twitter typeahead.js', 1),
#  ('General Electric Company', 'Chart.js', 1),
#  ('NRG Energy, Incorporated', 'Ubuntu', 1),
#  ('NRG Energy, Incorporated', 'Typekit', 1),
#  ('Occidental Petroleum Corporation', 'Material Design for Angular', 1),
#  ('Occidental Petroleum Corporation', 'Azure DevOps Server', 1),
#  ('Occidental Petroleum Corporation', 'C#', 1),
#  ('Occidental Petroleum Corporation', 'RabbitMQ', 1),
#  ('Occidental Petroleum Corporation', 'Angular', 1),
#  ('Occidental Petroleum Corporation', 'Xamarin', 1),
#  ('Occidental Petroleum Corporation', 'Jira', 1),
#  ('Occidental Petroleum Corporation', 'SonarQube', 1),
#  ('Occidental Petroleum Corporation', 'Protractor', 1),
#  ('Occidental Petroleum Corporation', 'Ionic', 1),
#  ('Occidental Petroleum Corporation', 'Azure Functions', 1),
#  ('Occidental Petroleum Corporation', 'Swagger UI', 1),
#  ('Occidental Petroleum Corporation', 'Git', 1),
#  ('Occidental Petroleum Corporation', 'Microsoft SQL Server', 1),
#  ('Occidental Petroleum Corporation', 'Visual Studio Code', 1),
#  ('Occidental Petroleum Corporation', '.NET', 1),
#  ('Occidental Petroleum Corporation', 'Sass', 1),
#  ('Occidental Petroleum Corporation', 'Objective-C', 1),
#  ('Occidental Petroleum Corporation', 'npm', 1),
#  ('Occidental Petroleum Corporation', 'Confluence', 1),
#  ('PepsiCo Incorporated', 'Sitefinity', 1),
#  ('PepsiCo Incorporated', 'TweenMax', 1),
#  ('Pfizer Incorporated', 'Dyn', 1),
#  ('Pfizer Incorporated', 'New Relic', 1),
#  ('Pfizer Incorporated', 'Azure CDN', 1),
#  ('Publix Super Markets, Incorporated', 'Google Maps', 1),
#  ('The Home Depot, Incorporated', 'Jenkins', 1),
#  ('The Home Depot, Incorporated', 'Prettier', 1),
#  ('The Home Depot, Incorporated', 'Polyfill', 1),
#  ('The Home Depot, Incorporated', 'Moment.js', 1),
#  ('The Home Depot, Incorporated', 'Enzyme', 1),
#  ('The Home Depot, Incorporated', 'Material Design Lite', 1),
#  ('The Home Depot, Incorporated', 'Jest', 1),
#  ('The Home Depot, Incorporated', 'Travis CI', 1),
#  ('The Home Depot, Incorporated', 'Shell', 1),
#  ('The Traverlers Companies, Incorporated', 'Prototype', 1),
#  ('The Traverlers Companies, Incorporated', 'XRegExp', 1),
#  ('The Traverlers Companies, Incorporated', 'Dynatrace', 1),
#  ('The Traverlers Companies, Incorporated', 'Netlify', 1),
#  ('United Natural Foods, Incorporated', 'UNIX', 1),
#  ('United Natural Foods, Incorporated', 'Clicky', 1),
#  ('Valero Energy Corporation', 'Webtrends', 1),
#  ('Valero Energy Corporation', 'Microsoft SharePoint', 1),
#  ('Visa Incorporated', 'Optimizely', 1),
#  ('Visa Incorporated', 'Google PageSpeed', 1),
#  ('Visa Incorporated', 'SinonJS', 1),
#  ('Visa Incorporated', 'Gradle', 1),
#  ('Visa Incorporated', 'Chai', 1),
#  ('Visa Incorporated', 'Puma', 1),
#  ('Wells Fargo & Company', 'MooTools', 1),
#  ('Wells Fargo & Company', 'Select2', 1),
#  ('Wells Fargo & Company', 'amCharts', 1)]

# %%
# %%sql
# WITH top_companies AS (
#     SELECT company_id
#     FROM Companies
#     ORDER BY company_revenue DESC
#     LIMIT 10
# ),
# tool_usage AS (
#     SELECT
#         ct.company_id,
#         t.tool_name,
#         COUNT(ct.tool_id) AS tool_frequency
#     FROM Company_Tool ct
#     JOIN Tools t
#         ON ct.tool_id = t.tool_id
#     JOIN top_companies tc
#         ON ct.company_id = tc.company_id
#     GROUP BY ct.company_id, t.tool_name
# )
# SELECT
#     tool_name,
#     SUM(tool_frequency) AS total_tool_frequency
# FROM tool_usage
# GROUP BY tool_name
# ORDER BY total_tool_frequency DESC
# LIMIT 5;
# Out:
#    mysql+mysqldb://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#    mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com/ISBA_4715_Project
#  * mysql+pymysql://admin:***@isba-dev-01.cd2h7smpaebz.us-east-1.rds.amazonaws.com:3306/ISBA_4715_Project
# 5 rows affected.
# [('jQuery', Decimal('8')),
#  ('ASP.NET', Decimal('7')),
#  ('Bootstrap', Decimal('7')),
#  ('Amazon Web Services', Decimal('7')),
#  ('IIS', Decimal('6'))]

# %%
# !pip install nbmerge
# Out:
# Collecting nbmerge
#   Downloading nbmerge-0.0.4.tar.gz (7.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: nbmerge
#   Building wheel for nbmerge (setup.py): started
#   Building wheel for nbmerge (setup.py): finished with status 'done'
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6393 sha256=5d96c21a9f48a3f0d95a71805493cba05287ae8a018360b159a482c82b1f5bd2
#   Stored in directory: c:\users\sambi\appdata\local\pip\cache\wheels\17\8b\74\63738d2dc1680a07d00f6ca14fa0feb6434d7d8b99f314e879
# Successfully built nbmerge
# Installing collected packages: nbmerge
# Successfully installed nbmerge-0.0.4

# %%
# !nbmerge data_collection.ipynb sql_analysis.ipynb -o presentation.ipynb
